# %%
parrafo = "El perro corre por el parque hacia la casa de su dueño, y contra, desde, luego va a jugar por la tarde con otros perros de la cuadra."

preposiciones = [
    "a", "ante", "bajo", "cabe", "con", "contra", "de", "desde", 
    "durante", "en", "entre", "hacia", "hasta", "mediante", "para", 
    "por", "según", "sin", "so", "sobre", "tras", "versus", "vía"
]

palabras = parrafo_limpio.split()
total_palabras = len(palabras)

preposiciones_encontradas = []
for palabra in palabras:
    if palabra in preposiciones:
        preposiciones_encontradas.append(palabra)

total_preposiciones = len(preposiciones_encontradas)

preposiciones_unicas = set(preposiciones_encontradas)
total_preposiciones_unicas = len(preposiciones_unicas)

resultados = {
    "total_de_palabras": total_palabras,
    "preposiciones_totales": total_preposiciones,
    "preposiciones_sin_repetir": total_preposiciones_unicas,
    "detalle_preposiciones_unicas": list(preposiciones_unicas) 
}

print("El diccionario con los resultados es:")
print(resultados)
# Out:
# El diccionario con los resultados es:
# {'total_de_palabras': 28, 'preposiciones_totales': 9, 'preposiciones_sin_repetir': 7, 'detalle_preposiciones_unicas': ['de', 'hacia', 'por', 'con', 'desde', 'contra', 'a']}
